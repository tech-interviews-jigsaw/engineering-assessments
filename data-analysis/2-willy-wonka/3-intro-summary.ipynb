# %% [markdown]
# # Exploring Willy Wonka

# %% [markdown]
# ### Introduction

# %% [markdown]
# Use this notebook to just select the interesting graphs to present to a manager.  It's good to have this before going too deeply, as you may run out of time or go down a rabbit hole if you dig too deeply.
#
# A good process is to begin by writing down some insights, or initial questions.  And have the graphs below each insight to support them.

# %%
from lib import load_data
import pandas as pd

engine, df = load_data()
df[:1]
# Out:
#        order_id        user_id  list_sku list_sku_category list_sku_flavor  \
# 0  TXN-52889719  USER-16961214  SKU-3002        Energy Bar   Peanut Butter
#
#   list_lineitem_id order_date  month  week  day_of_week  ...  \
# 0  ITEM-2009089674 2021-05-04    5.0  18.0          2.0  ...
#
#    order_coupon_code  order_referrer  order_ad_shown order_store_city  \
# 0           express5       Microsoft       week40_10           Dallas
#
#   order_store_id order_day_part order_is_freeshipping user_loyalty_program  \
# 0       Dallas-3        evening                     1               bronze
#
#   user_age user_gender
# 0       49           F
#
# [1 rows x 24 columns]

# %%
from lib import print_grouped_bys, group_and_print

# %%
order_cols = ['order_single_item', 'order_date', 'order_id', 'order_item_count']
timing_cols = ['order_day_part', 'order_date']
location_cols = ['order_store_city', 'order_store_id']

# %% [markdown]
# ### Consumer Insights
#
# * Revenue peaks at 27 - 30 year olds, with more spending by females

# %%
from lib import group_and_print
user_cols = ['user_age', 'user_gender', 'user_id']
group_and_print('raw_lineitems', user_cols[:-1], engine)
# Out:
# user_age
# user_gender

# %% [markdown]
# ### Product Insights

# %% [markdown]
# * Top six products skus dominate revenue.
# * Energy shot, granola bar, protein bar, energy drink, energy bar.
#
# > To do -- are list_sku's the same as list_sku_categories?

# %%
product_cols = ['list_sku', 'list_sku_category', 'list_sku_flavor'] 
group_and_print('raw_lineitems', product_cols, engine) # top
# Out:
# list_sku
# list_sku_category
# list_sku_flavor

# %% [markdown]
# ### Marketing Insights

# %% [markdown]
# * Digital mobile and instore are highest, whereas digital wholesale and direct lag.  Wholesale may indicate poor business to business, whereas lag in digital direct is surprising considering highpoints in mobile and in store.  What's going on there?
# * Google and facebook dominate, followed by yahoo.  Could be interesting to see if they reach different market segments.  For that a pivot table could be useful.
# * User loyalty program is surprising -- why do silver and none dominate?  Would be good to learn more about if the silver loyalty program actually contributes to more sales, or if it's just correlated.  Overall, the lack of a trend, and dominance of none suggests room for improvement with the loyalty program.

# %%
marketing_cols = ['order_channel', 'order_referrer', 'order_ad_shown', 'order_is_freeshipping', 'user_loyalty_program']

group_and_print('raw_lineitems', marketing_cols, engine)
# Out:
# order_channel
# order_referrer
# order_ad_shown
# order_is_freeshipping
# user_loyalty_program
